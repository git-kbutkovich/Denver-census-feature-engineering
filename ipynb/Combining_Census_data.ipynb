# %%
import pandas as pd

# %%
df = pd.read_pickle('../pickle_jar/df.p')
demographics = pd.read_pickle('../pickle_jar/demographics_df.p')
housing = pd.read_pickle('../pickle_jar/housing_high_low_df.p')
household = pd.read_pickle('../pickle_jar/household_high_low.p')

# %%
demographics.head()
# Out:
#         NBRHD_NAME  POPULATION_2010  HISPANIC_2010  WHITE_2010  BLACK_2010  \
# 1          Hampden          17547.0         2505.0     11750.0      1963.0
# 2            Baker           4879.0         1664.0      2854.0       144.0
# 3  Washington Park           6905.0          295.0      6356.0        28.0
# 4     Cherry Creek           5589.0          332.0      4896.0        79.0
# 5     Country Club           3001.0           94.0      2740.0        20.0
#
#    NATIVEAM_2010  ASIAN_2010  HAWPACIS_2010  OTHER_2010  TWO_OR_MORE_2010  \
# 1           64.0       726.0           20.0        38.0             481.0
# 2           43.0        52.0           10.0         7.0             105.0
# 3            9.0       119.0            3.0        13.0              82.0
# 4           17.0       168.0            4.0         3.0              90.0
# 5            8.0        77.0            1.0         5.0              56.0
#
# ...

# %%
housing.head()
# Out:
#   HOUSING_UNITS HU_OWNED HU_RENTED OCCUPIED_HU OWNED_FREE_CLEAR  \
# 1          high     high      high        high             high
# 2       average  average   average     average            lower
# 3       average  average     lower     average             high
# 4       average  average   average     average          average
# 5         lower  average     lower       lower          average
#
#   OWNED_W_MORTG_LOAN   RENTED VACANT_FOR_RENT VACANT_FOR_SALE VACANT_HU  \
# 1               high     high            high         average      high
# 2            average  average         average         average   average
# 3            average    lower           lower         average   average
# 4            average  average         average         average      high
# 5            average    lower           lower           lower     lower
#
#   VACANT_OTHER VACANT_RENTED_NOT_OCC VACANT_SEASONAL VACANT_SOLD_NOT_OCC
# 1         high                  high         average                high
# ...

# %%
household.head()
# Out:
#   FAMILIES FAMILY_HHLD FEMALE_HHLDR_NO_CHILDR FEMALE_HHLDR_NO_HUSB  \
# 1     high        high                   high                 high
# 2  average     average                average              average
# 3  average     average                  lower                lower
# 4  average     average                average                lower
# 5  average     average                  lower                lower
#
#   FEMALE_HHLDR_W_CHILDR HH_NO_NONRELATIVES HH_W_NONRELATIVES HUSB_WIFE_FAM  \
# 1                  high               high              high          high
# 2                 lower            average           average       average
# 3                 lower            average           average       average
# 4                 lower            average           average       average
# 5                 lower              lower             lower       average
#
#   HUSB_WIFE_NO_CHILD HUSB_WIFE_W_CHLDR          ...           \
# ...

# %%
demographics.shape, housing.shape, household.shape
# Out:
# ((78, 25), (78, 14), (78, 22))

# %%
combined = pd.concat([demographics, housing, household], axis=1)
combined.shape
# Out:
# (78, 61)

# %%
combined.sample(20)
# Out:
#            NBRHD_NAME  POPULATION_2010  HISPANIC_2010  WHITE_2010  BLACK_2010  \
# 19     Cory - Merrill           3892.0          238.0      3440.0        38.0
# 30   University Hills           5327.0          540.0      4376.0       153.0
# 8      City Park West           4844.0          524.0      2981.0       995.0
# 56           Overland           2218.0          678.0      1337.0        75.0
# 68     Jefferson Park           2552.0         1419.0       991.0        37.0
# 5        Country Club           3001.0           94.0      2740.0        20.0
# 39  Harvey Park South           8393.0         3925.0      3641.0       171.0
# 4        Cherry Creek           5589.0          332.0      4896.0        79.0
# 63         Sloan Lake           7238.0         2376.0      4274.0       124.0
# 71       Chaffee Park           3874.0         2548.0      1194.0        36.0
# 41        Barnum West           5376.0         4016.0      1151.0        40.0
# ...

# %%
combined.to_pickle('../pickle_jar/combined.p')

# %%
combined['NBRHD_NAME'] = combined['NBRHD_NAME'].str.lower()

# %%
combined['NBRHD_NAME'] = combined['NBRHD_NAME'].str.replace(' \ ', '-')
combined['NBRHD_NAME']
# Out:
# 1                         hampden
# 2                           baker
# 3                 washington-park
# 4                    cherry-creek
# 5                    country-club
# 6                         clayton
# 7                         skyland
# 8                  city-park-west
# 9                    capitol-hill
# 10             north-capitol-hill
# 11                   civic-center
# 12                            cbd
# 13                  union-station
# 14                    five-points
# 15                      stapleton
# 16                       highland
# 17                     globeville
# 18                university-park
# 19                 cory---merrill
# 20           washington-park-west
# 21                          speer
# 22                  congress-park
# 23                           cole
# 24                      sunnyside
# 25                      ruby-hill
# 26                     university
# 27                      goldsmith
# ...

# %%
combined.loc[combined['NBRHD_NAME'].str.contains('/'), :]
# Out:
#                       NBRHD_NAME  POPULATION_2010  HISPANIC_2010  WHITE_2010  \
# 40  gateway-/-green-valley-ranch          29201.0        10818.0      7003.0
# 52   college-view-/-south-platte           6498.0         4408.0      1228.0
#
#     BLACK_2010  NATIVEAM_2010  ASIAN_2010  HAWPACIS_2010  OTHER_2010  \
# 40      8305.0          108.0      1655.0          110.0        65.0
# 52       165.0           78.0       515.0           12.0        18.0
#
#     TWO_OR_MORE_2010          ...            MALE_HHLDR_W_CHLDR  \
# 40            1137.0          ...                          high
# 52              74.0          ...                       average
#
#     NON_FAMILY_FEMALE_HHLDR  NON_FAMILY_HH  NON_FAMILY_MALE_HHLDR  \
# 40                  average        average                average
# 52                    lower          lower                average
#
#     NUM_HOUSEHOLDS  ONE_PERSON_HH  ONE_PERSON_HH_FEMALE  ONE_PERSON_HH_MALE  \
# ...

# %%
combined['NBRHD_NAME'] = combined['NBRHD_NAME'].str.replace('-/-', '-')
combined['NBRHD_NAME'] = combined['NBRHD_NAME'].str.replace('--', '-')
combined['NBRHD_NAME']
# Out:
# 1                       hampden
# 2                         baker
# 3               washington-park
# 4                  cherry-creek
# 5                  country-club
# 6                       clayton
# 7                       skyland
# 8                city-park-west
# 9                  capitol-hill
# 10           north-capitol-hill
# 11                 civic-center
# 12                          cbd
# 13                union-station
# 14                  five-points
# 15                    stapleton
# 16                     highland
# 17                   globeville
# 18              university-park
# 19                 cory-merrill
# 20         washington-park-west
# 21                        speer
# 22                congress-park
# 23                         cole
# 24                    sunnyside
# 25                    ruby-hill
# 26                   university
# 27                    goldsmith
# 28             virginia-village
# 29                          dia
# ...

# %%
combined.loc[combined['NBRHD_NAME'].str.contains('virginia'), :]
# Out:
#                   NBRHD_NAME  POPULATION_2010  HISPANIC_2010  WHITE_2010  \
# 28          virginia-village          12844.0         2488.0      8453.0
# 46  washington-virginia-vale          13030.0         1770.0      8003.0
#
#     BLACK_2010  NATIVEAM_2010  ASIAN_2010  HAWPACIS_2010  OTHER_2010  \
# 28      1007.0           82.0       437.0            5.0        28.0
# 46      1943.0           57.0       858.0           14.0        37.0
#
#     TWO_OR_MORE_2010          ...            MALE_HHLDR_W_CHLDR  \
# 28             344.0          ...                       average
# 46             348.0          ...                       average
#
#     NON_FAMILY_FEMALE_HHLDR  NON_FAMILY_HH  NON_FAMILY_MALE_HHLDR  \
# 28                  average        average                average
# 46                     high           high                   high
#
#     NUM_HOUSEHOLDS  ONE_PERSON_HH  ONE_PERSON_HH_FEMALE  ONE_PERSON_HH_MALE  \
# ...
